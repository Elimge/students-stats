# %% [markdown]
# # HU_SM4_01: Student Performance Analysis
#
# ## Objective
# To obtain a reliable analysis of student performance to identify patterns in attendance, effort, and final results, in order to improve support strategies.
#
# ---
#
# ### Task 1: Initial Data Exploration

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# CA_01: Load the student dataset.
# The dataset is separated by semicolons, so we use sep=';'.
file_path = 'student-mat.csv'
df = pd.read_csv(file_path, sep=';')

# Display basic information about the dataframe
print("--- Initial Data Load ---")
print(f"Dataset shape: {df.shape}") # Shows (rows, columns)
print("\nFirst 5 rows of the dataset:")
print(df.head())
print("\nInformation about columns, types, and null values:")
df.info()
# Out:
# --- Initial Data Load ---
# Dataset shape: (395, 33)
#
# First 5 rows of the dataset:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]
#
# Information about columns, types, and null values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
#  19  nursery     395 non-null    object
#  20  higher      395 non-null    object
#  21  internet    395 non-null    object
#  22  romantic    395 non-null    object
#  23  famrel      395 non-null    int64
#  24  freetime    395 non-null    int64
#  25  goout       395 non-null    int64
#  26  Dalc        395 non-null    int64
#  27  Walc        395 non-null    int64
#  28  health      395 non-null    int64
#  29  absences    395 non-null    int64
#  30  G1          395 non-null    int64
#  31  G2          395 non-null    int64
#  32  G3          395 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 102.0+ KB

# %%
# CA_02: Select specific numeric columns of interest.
columns_of_interest = ['age', 'studytime', 'failures', 'absences', 'G1', 'G2', 'G3']
df_selected = df[columns_of_interest].copy()

print("\n--- Selected Columns ---")
print("First 5 rows of the selected data:")
print(df_selected.head())

# CA_03: Filter and display students older than 18 years.
students_over_18 = df[df['age'] > 18].copy()

print("\n--- Students Older Than 18 ---")
print(f"Found {students_over_18.shape[0]} students older than 18.")
print(students_over_18.head())

# CA_04: Filter and display students with more than 20 absences.
students_high_absences = df[df['absences'] > 20].copy()

print("\n--- Students with More Than 20 Absences ---")
print(f"Found {students_high_absences.shape[0]} students with more than 20 absences.")
print(students_high_absences.head())
# Out:
# --- Selected Columns ---
# First 5 rows of the selected data:
#    age  studytime  failures  absences  G1  G2  G3
# 0   18          2         0         6   5   6   6
# 1   17          2         0         4   5   5   6
# 2   15          2         3        10   7   8  10
# 3   15          3         0         2  15  14  15
# 4   16          2         0         4   6  10  10
#
# --- Students Older Than 18 ---
# Found 29 students older than 18.
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 127     GP   F   19       U     GT3       T     0     1   at_home     other
# 153     GP   M   19       U     GT3       T     3     2  services   at_home
# 210     GP   F   19       U     GT3       T     3     3     other     other
# 247     GP   M   22       U     GT3       T     3     1  services  services
# 257     GP   M   19       U     LE3       A     4     3  services   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 127  ...      3        4      2     1     1      5        2   7   8   9
# 153  ...      4        5      4     1     1      4        0   5   0   0
# 210  ...      4        3      3     1     2      3       10   8   8   8
# 247  ...      5        4      5     5     5      1       16   6   8   8
# 257  ...      4        3      1     1     1      1       12  11  11  11
#
# [5 rows x 33 columns]
#
# --- Students with More Than 20 Absences ---
# Found 15 students with more than 20 absences.
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 40      GP   F   16       U     LE3       T     2     2     other     other
# 74      GP   F   16       U     GT3       T     3     3     other  services
# 103     GP   F   15       U     GT3       T     3     2  services     other
# 183     GP   F   17       U     LE3       T     3     3     other     other
# 198     GP   F   17       U     GT3       T     4     4  services   teacher
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 40   ...      3        3      3     1     2      3       25   7  10  11
# 74   ...      4        3      3     2     4      5       54  11  12  11
# 103  ...      4        3      5     1     1      2       26   7   6   6
# 183  ...      5        3      3     2     3      1       56   9   9   8
# 198  ...      4        2      4     2     3      2       24  18  18  18
#
# [5 rows x 33 columns]

# %% [markdown]
# ---
# ### Task 2: Data Quality Check

# %%
print("--- TASK 2: Data Quality Check ---")
print(f"Initial number of rows: {df.shape[0]}")

# CA_05: Identify and remove duplicate records.
# First, let's count how many complete duplicate rows exist.
duplicate_rows = df.duplicated().sum()
print(f"\nFound {duplicate_rows} duplicate rows.")

# If there are duplicates, remove them.
if duplicate_rows > 0:
    df_cleaned = df.drop_duplicates().copy()
    print(f"Number of rows after removing duplicates: {df_cleaned.shape[0]}")
else:
    df_cleaned = df.copy()
    print("No duplicate rows to remove.")

# From now on, we will work with the cleaned dataframe.
# Out:
# --- TASK 2: Data Quality Check ---
# Initial number of rows: 395
#
# Found 0 duplicate rows.
# No duplicate rows to remove.

# %%
# CA_07: Validate that grades (G1, G2, G3) are within the official range of 0-20.
# We can use the .describe() method for a quick statistical overview.
print("\n--- Grade Validation (G1, G2, G3) ---")
grade_stats = df_cleaned[['G1', 'G2', 'G3']].describe()
print(grade_stats)

# Check if any grade is outside the 0-20 range.
invalid_g1 = df_cleaned[(df_cleaned['G1'] < 0) | (df_cleaned['G1'] > 20)].shape[0]
invalid_g2 = df_cleaned[(df_cleaned['G2'] < 0) | (df_cleaned['G2'] > 20)].shape[0]
invalid_g3 = df_cleaned[(df_cleaned['G3'] < 0) | (df_cleaned['G3'] > 20)].shape[0]

if (invalid_g1 + invalid_g2 + invalid_g3) == 0:
    print("\nConfirmation: All grades are within the valid range of 0-20.")
else:
    print(f"\nWarning: Found {invalid_g1} invalid G1, {invalid_g2} invalid G2, {invalid_g3} invalid G3 grades.")


# CA_06: Detect outliers in 'absences' and final grades 'G3'.
# We'll use the Interquartile Range (IQR) method, a common statistical approach.
print("\n--- Outlier Detection (IQR Method) ---")

def detect_outliers(data, column_name):
    """Detects outliers in a specific column using the IQR method."""
    print(f"\nAnalyzing outliers for '{column_name}':")
    Q1 = data[column_name].quantile(0.25)
    Q3 = data[column_name].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Find the outliers
    outliers = data[(data[column_name] < lower_bound) | (data[column_name] > upper_bound)]
    
    print(f"Interquartile Range (IQR): {IQR}")
    print(f"Lower bound for outliers: {lower_bound:.2f}")
    print(f"Upper bound for outliers: {upper_bound:.2f}")
    print(f"Number of outliers detected: {len(outliers)}")
    
    if not outliers.empty:
        print("Example outliers found:")
        print(outliers.head())
    
    return outliers

# Detect outliers for 'absences' and 'G3'
outliers_absences = detect_outliers(df_cleaned, 'absences')
outliers_g3 = detect_outliers(df_cleaned, 'G3')
# Out:
# --- Grade Validation (G1, G2, G3) ---
#                G1          G2          G3
# count  395.000000  395.000000  395.000000
# mean    10.908861   10.713924   10.415190
# std      3.319195    3.761505    4.581443
# min      3.000000    0.000000    0.000000
# 25%      8.000000    9.000000    8.000000
# 50%     11.000000   11.000000   11.000000
# 75%     13.000000   13.000000   14.000000
# max     19.000000   19.000000   20.000000
#
# Confirmation: All grades are within the valid range of 0-20.
#
# --- Outlier Detection (IQR Method) ---
#
# Analyzing outliers for 'absences':
# Interquartile Range (IQR): 8.0
# Lower bound for outliers: -12.00
# Upper bound for outliers: 20.00
# Number of outliers detected: 15
# Example outliers found:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 40      GP   F   16       U     LE3       T     2     2     other     other
# 74      GP   F   16       U     GT3       T     3     3     other  services
# 103     GP   F   15       U     GT3       T     3     2  services     other
# 183     GP   F   17       U     LE3       T     3     3     other     other
# 198     GP   F   17       U     GT3       T     4     4  services   teacher
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 40   ...      3        3      3     1     2      3       25   7  10  11
# 74   ...      4        3      3     2     4      5       54  11  12  11
# 103  ...      4        3      5     1     1      2       26   7   6   6
# 183  ...      5        3      3     2     3      1       56   9   9   8
# 198  ...      4        2      4     2     3      2       24  18  18  18
#
# [5 rows x 33 columns]
#
# Analyzing outliers for 'G3':
# Interquartile Range (IQR): 6.0
# Lower bound for outliers: -1.00
# Upper bound for outliers: 23.00
# Number of outliers detected: 0

# %% [markdown]
# ---
# ### TASK 3: Basic Performance Indicators

# %%
print("--- TASK 3: Basic Performance Indicators ---")

# CA_07: Average, minimum, and maximum of the final grade (G3).
print("\n--- Final Grade (G3) Statistics ---")
avg_g3 = df_cleaned['G3'].mean()
min_g3 = df_cleaned['G3'].min()
max_g3 = df_cleaned['G3'].max()

print(f"Average Final Grade: {avg_g3:.2f}")
print(f"Minimum Final Grade: {min_g3}")
print(f"Maximum Final Grade: {max_g3}")

# CA_08: Number of students per study time level.
# The 'studytime' column is categorical: 1 (<2h), 2 (2-5h), 3 (5-10h), 4 (>10h).
print("\n--- Students per Study Time Level ---")
studytime_counts = df_cleaned['studytime'].value_counts().sort_index()
print(studytime_counts)
# .sort_index() is used to order the results by the study time level (1, 2, 3, 4).

# CA_09: General average of absences.
print("\n--- Absences Statistics ---")
avg_absences = df_cleaned['absences'].mean()
print(f"Average number of absences: {avg_absences:.2f}")
# Out:
# --- TASK 3: Basic Performance Indicators ---
#
# --- Final Grade (G3) Statistics ---
# Average Final Grade: 10.42
# Minimum Final Grade: 0
# Maximum Final Grade: 20
#
# --- Students per Study Time Level ---
# studytime
# 1    105
# 2    198
# 3     65
# 4     27
# Name: count, dtype: int64
#
# --- Absences Statistics ---
# Average number of absences: 5.71

# %% [markdown]
# ---
# ### TASK 4: Complementary Indicators

# %%
print("--- TASK 4: Complementary Indicators ---")

# CA_11: Percentage of approved (final grade >= 10) and failed students.
print("\n--- Student Approval Status ---")

# Create a new column 'status' based on the final grade 'G3'.
# np.where for a fast conditional assignment.
df_cleaned['status'] = np.where(df_cleaned['G3'] >= 10, 'Approved', 'Failed')

# Calculate the percentage using value_counts with normalize=True.
status_percentage = df_cleaned['status'].value_counts(normalize=True) * 100

print(status_percentage)


# Distribution of absences in levels (low, medium, high).
print("\n--- Distribution of Absences ---")
print(df_cleaned['absences'].describe())

# Based on the stats (e.g., 25th percentile is 0, 50th is 4, 75th is 8),
# Logical bins can be created.
# Bins: [0-2], [3-8], [9+]
bins = [-1, 2, 8, df_cleaned['absences'].max() + 1]
labels = ['Low (0-2 days)', 'Medium (3-8 days)', 'High (9+ days)']
df_cleaned['absence_level'] = pd.cut(df_cleaned['absences'], bins=bins, labels=labels)

print("\nNumber of students per absence level:")
print(df_cleaned['absence_level'].value_counts().sort_index())

# Normalization of final grades for comparative analysis.
# Using Min-Max normalization to scale grades to a range of [0, 1].
print("\n--- Normalization of Final Grades (G3) ---")
g3_column = df_cleaned['G3']
normalized_g3 = (g3_column - g3_column.min()) / (g3_column.max() - g3_column.min())
df_cleaned['G3_normalized'] = normalized_g3

# Show stats of the normalized column to confirm the range is [0, 1].
print("Descriptive statistics for normalized G3:")
print(df_cleaned['G3_normalized'].describe())

# CA_13: Percentiles of absences.
print("\n--- Percentiles for Absences ---")
absences_p25 = df_cleaned['absences'].quantile(0.25)
absences_p50 = df_cleaned['absences'].quantile(0.50) # This is the median
absences_p75 = df_cleaned['absences'].quantile(0.75)
absences_p95 = df_cleaned['absences'].quantile(0.95) # 95th percentile

print(f"25th Percentile: {absences_p25} (25% of students have this many absences or fewer)")
print(f"50th Percentile (Median): {absences_p50}")
print(f"75th Percentile: {absences_p75}")
print(f"95th Percentile: {absences_p95} (Only 5% of students have more absences than this)")
# Out:
# --- TASK 4: Complementary Indicators ---
#
# --- Student Approval Status ---
# status
# Approved    67.088608
# Failed      32.911392
# Name: proportion, dtype: float64
#
# --- Distribution of Absences ---
# count    395.000000
# mean       5.708861
# std        8.003096
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        8.000000
# max       75.000000
# Name: absences, dtype: float64
#
# Number of students per absence level:
# absence_level
# Low (0-2 days)       183
# Medium (3-8 days)    126
# High (9+ days)        86
# Name: count, dtype: int64
#
# --- Normalization of Final Grades (G3) ---
# Descriptive statistics for normalized G3:
# count    395.000000
# mean       0.520759
# std        0.229072
# min        0.000000
# 25%        0.400000
# 50%        0.550000
# 75%        0.700000
# max        1.000000
# Name: G3_normalized, dtype: float64
#
# --- Percentiles for Absences ---
# 25th Percentile: 0.0 (25% of students have this many absences or fewer)
# 50th Percentile (Median): 4.0
# 75th Percentile: 8.0
# 95th Percentile: 18.299999999999955 (Only 5% of students have more absences than this)

# %% [markdown]
# ---
# ### Final KPI Report

# %%
# --- KPI 1: Average absences by age group ---
print("--- Average Absences per Age Group ---")
avg_absences_by_age = df_cleaned.groupby('age')['absences'].mean().round(2)
print(avg_absences_by_age)


# --- KPI 2: Total students by sex ---
print("\n--- Total Students by Sex ---")
students_by_sex = df_cleaned['sex'].value_counts()
print(students_by_sex)


# --- KPI 3: Average G3 for students with high vs. low study time ---
print("\n--- Average Final Grade (G3) by Study Time Level ---")
# We'll define 'Low' study time as levels 1 & 2 (<5 hours)
# and 'High' study time as levels 3 & 4 (5+ hours).
studytime_map = {1: 'Low', 2: 'Low', 3: 'High', 4: 'High'}
df_cleaned['studytime_level'] = df_cleaned['studytime'].map(studytime_map)

avg_g3_by_studytime = df_cleaned.groupby('studytime_level')['G3'].mean().round(2)
print(avg_g3_by_studytime)


# --- KPI 4: G3 Distribution (min, max, mean, median) ---
print("\n--- Final Grade (G3) Distribution ---")
g3_distribution = df_cleaned['G3'].agg(['min', 'max', 'mean', 'median']).round(2)
print(g3_distribution)
